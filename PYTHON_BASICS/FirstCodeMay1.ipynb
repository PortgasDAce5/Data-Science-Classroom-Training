# %%
import sys
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# # work with number

# %%
5
# Out:
# 5

# %%
3
# Out:
# 3

# %%
3+5
# Out:
# 8

# %%
10-5
# Out:
# 5

# %%
10/5 #float division
# Out:
# 2.0

# %%
10//5 #int division
# Out:
# 2

# %%
10*5
# Out:
# 50

# %%
3**2 #square
# Out:
# 9

# %%
10%5 #modulus
# Out:
# 0

# %%
_ #underscore stores previous values
# Out:
# '{"dataframes": [], "user": "manme"}'

# %%
print(repr(_))
print(type(_))
# Out:
# '{"dataframes": [], "user": "manme"}'
# <class 'str'>

# %%
3 * 2
# Out:
# 6

# %%
5 * 2
# Out:
# 10

# %%
2 * 4
# Out:
# 8

# %%
5 + 4
# Out:
# 9

# %%
2 + 5
3 - 1
5 + 2 #only takes recent executions
# Out:
# 7

# %%
print(2 + 5)
print(3 - 1)
print(5 + 2)
# Out:
# 7
# 2
# 7

# %% [markdown]
# # work with text

# %%
"apple"
# Out:
# 'apple'

# %%
'''apple
fruit 
is 
good for health'''
# Out:
# 'apple\nfruit \nis \ngood for health'

# %%
v = 5
print(v)
# Out:
# 5

# %%
id(v)
# Out:
# 140712701109288

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
a = 5
type(a)
# Out:
# int

# %%
petrol = 110.34
type(petrol)
# Out:
# float

# %%
a = 5e2
a
# Out:
# 500.0

# %%
type(a)
# Out:
# float

# %%
True + False
# Out:
# 1

# %%
True + True
# Out:
# 2

# %%
t = True 
f = False
print(t+f)
print(t-f)
print(t*f)
print(f/t)
# Out:
# 1
# 1
# 0
# 0.0

# %%
type(t)
# Out:
# bool

# %%
c = 10 + 20j
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
d = 20 + 30j
print(c + d)
# Out:
# (30+50j)

# %% [markdown]
# #String

# %%
s = "welcome"

# %%
len(s)
# Out:
# 7

# %%
s4 = "welcome"
s4
# Out:
# 'welcome'

# %%
print(s)
print(s4)
# Out:
# welcome
# welcome

# %%
print(id(s))
print(id(s4))  #2 variables in same memory
# Out:
# 2514099092864
# 2514099092864

# %%
s[3] #forward indexing
# Out:
# 'c'

# %%
s4[3]
# Out:
# 'c'

# %%
s[-2] #backward indexing
# Out:
# 'm'

# %%
s[2:4] #forward Slicing
# Out:
# 'lc'

# %%
s[2:]
# Out:
# 'lcome'

# %%
s[:6]
# Out:
# 'welcom'

# %%
s[1:6:2] #advance indexing
# Out:
# 'ecm'

# %%
s[:1000] #no error here
# Out:
# 'welcome'

# %%
 s[-2:]
# Out:
# 'me'

# %%
s[-6:-1] #backward slicing
# Out:
# 'elcom'

# %% [markdown]
# # type casting

# %%
#convert other datatype to int
int(3.5) #float to int
# Out:
# 3

# %%
int(True) #boolean to int
# Out:
# 1

# %%
int('10') #no. string to integer
# Out:
# 10

# %%
float(23) #int to float
# Out:
# 23.0

# %%
float(True) #bool to float
# Out:
# 1.0

# %%
float("2.3") #floatString to float
# Out:
# 2.3

# %%
bool(2) #int to bool
# Out:
# True

# %%
bool(13)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(2.5)
# Out:
# True

# %%
bool(2+3j)
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool(None)
# Out:
# False

# %%
bool('ten')
# Out:
# True

# %%
complex(10) #converting to complex
# Out:
# (10+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(2.5)
# Out:
# (2.5+0j)

# %%
complex(2.5,3.1)
# Out:
# (2.5+3.1j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False,False)
# Out:
# 0j

# %%
complex("10")
# Out:
# (10+0j)

# %%
complex('10.3')
# Out:
# (10.3+0j)

# %%
str(23) #converting to string
# Out:
# '23'

# %%
str(1.1)
# Out:
# '1.1'

# %%
str(False)
# Out:
# 'False'

# %%
str(5+3j)
# Out:
# '(5+3j)'

# %% [markdown]
#  # Airthmetic Operators

# %%
x1,y1 = 10,5

# %%
x1 + y1
# Out:
# 15

# %%
x1 - y1
# Out:
# 5

# %%
x1 * y1
# Out:
# 50

# %%
x1 / y1
# Out:
# 2.0

# %%
x1 // y1
# Out:
# 2

# %%
x1 % y1
# Out:
# 0

# %%
x1 ** y1
# Out:
# 100000

# %% [markdown]
# # Assignment Operator

# %%
x = 2
x
# Out:
# 2

# %%
x = x + 2
x
# Out:
# 4

# %%
x += 2
x
# Out:
# 6

# %%
x -= 2
x
# Out:
# 4

# %%
x *= 2
x
# Out:
# 8

# %%
x /= 2

# %%
x
# Out:
# 4.0

# %%
x //= 2
x
# Out:
# 2.0

# %%
x *= 8
x
# Out:
# 16.0

# %%
int(x)
# Out:
# 16

# %%
x /= 2
x
# Out:
# 8.0

# %%
int(x)
x //= 2
x
# Out:
# 4.0

# %%
int(x)
# Out:
# 4

# %%
x //= 2
x
# Out:
# 2.0

# %%
x = int(x) // 1
x
# Out:
# 2

# %% [markdown]
# # Relational Operator

# %%
a,b = 5,6

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a <= b
# Out:
# True

# %% [markdown]
# # Logical Operators

# %%
a = 5 
b = 4

# %%
a < 8 and b < 5 #refer to the truth table
# Out:
# True

# %%
a < 8 and b < 2
# Out:
# False

# %%
a < 8 or b < 2
# Out:
# True

# %%
a>8 or b<2
# Out:
# False

# %%
x = False
not x
# Out:
# True

# %% [markdown]
# # Unary Operator

# %%
n = 3
-n
# Out:
# -3

# %%
m=4
m
# Out:
# 4

# %%
p = -(m)
p
# Out:
# -4

# %% [markdown]
# # Number System

# %%
25
bin(25) #decimal to binary
# Out:
# '0b11001'

# %%
int(0b11001) #bin to decimal
# Out:
# 25

# %%
oct(25) #decimal to octal
# Out:
# '0o31'

# %%
0o31
# Out:
# 25

# %%
hex(25) #decimal to hexadecimal
# Out:
# '0x19'

# %%
hex(16)
# Out:
# '0x10'

# %%
print(hex(1))
print(hex(2))
print(hex(3))
print(hex(4))
print(hex(5))
print(hex(6))
print(hex(7))
print(hex(8))
print(hex(9))
print(hex(10))
# Out:
# 0x1
# 0x2
# 0x3
# 0x4
# 0x5
# 0x6
# 0x7
# 0x8
# 0x9
# 0xa

# %%
print(hex(11))
print(hex(12))
print(hex(13))
print(hex(14))
print(hex(15))
print(hex(16))
print(hex(17))
# Out:
# 0xb
# 0xc
# 0xd
# 0xe
# 0xf
# 0x10
# 0x11

# %%
0x14
# Out:
# 20

# %%
hex(234)
# Out:
# '0xea'

# %%
int(0xea)
# Out:
# 234

# %% [raw]
# # Bitwise Operator

# %%
~2 #complement operator
# Out:
# -3

# %%
~54
# Out:
# -55

# %%
12 & 13 #bitwise and
# Out:
# 12

# %%
12 | 13 #bitwise or
# Out:
# 13

# %%
12 & 10
# Out:
# 8

# %%
1 & 0
# Out:
# 0

# %%
1 | 0
# Out:
# 1

# %%
12 ^ 13 #Xor
# Out:
# 1

# %%
25 ^ 30
# Out:
# 7

# %%
12 << 2 #left shift
# Out:
# 48

# %%
12 >> 2 #right shift
# Out:
# 3

# %%
13 << 1
# Out:
# 26

# %%
12 >> 3
# Out:
# 1

# %% [markdown]
# # Math Module

# %%
import math #importing module
math.sqrt(25) #using function of that module
# Out:
# 5.0

# %%
x = math.sqrt(36)
x
# Out:
# 6.0

# %%
round(x) #round funtion
# Out:
# 6

# %%
math.floor(3.7) #floor function
# Out:
# 3

# %%
math.ceil(3.7) #ceiling funtion
# Out:
# 4

# %%
import math as m
m.floor(4.9)
# Out:
# 4

# %%
from math import *  
print(pow(2,3))
print(floor(2.6))
print(ceil(3.4))
print(sqrt(49))
# Out:
# 8.0
# 2
# 4
# 7.0

# %%
help()
# Out:
# Welcome to Python 3.13's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.13/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q", "quit" or "exit".
# help>  math
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
# ...

# %% [markdown]
# # input() funtion

# %%
x = input()
x
# Out:
#  hey buddy
# 'hey buddy'

# %%
x = input()
y = input()
z = x+y
print(z) #all 3 are by default of string class
# Out:
#  2
#  3
# 23

# %%
x1 = int(input('enter the first number'))
y1 = int(input('enter the second number'))
z1 = x1 + y1
z1
# Out:
# enter the first number 5
# enter the second number 6
# 11

# %%
st = input('enter a string')
print(st)
# Out:
# enter a string hello
# hello

# %%
print(st[0])  #input indexing
# Out:
# h

# %%
print(st[1:4])  #input slicing
# Out:
# ell

# %%
st = input('enter a string')[2]
print(st)
# Out:
# enter a string hello
# l

# %%
st = input('enter a string')[2:5]
st
# Out:
# enter a string hello
# 'llo'

# %%
result = eval(input('enter an exp'))  #eavluating expresssions
print(result)
# Out:
# enter an exp 2 + 4 * 6 // 3 - 1
# 9
